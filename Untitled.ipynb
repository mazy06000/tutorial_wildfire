# %%
INSTANCE_ID = '085cff69-dbb0-4521-bdfc-4cf6e34a9061'  # In case you put instance ID into configuration file you can leave this unchanged

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import datetime
import numpy as np

from sentinelhub import SHConfig

config = SHConfig()
config.instance_id = INSTANCE_ID

import matplotlib.pyplot as plt
from sentinelhub import WmsRequest, WcsRequest, MimeType, CRS, BBox
def plot_image(image, factor=1):
    """
    Utility function for plotting RGB images.
    """
    fig = plt.subplots(nrows=1, ncols=1, figsize=(15, 7))

    if np.issubdtype(image.dtype, np.floating):
        plt.imshow(np.minimum(image * factor, 1))
    else:
        plt.imshow(image)

from sentinelhub import CustomUrlParam


# Tip: if you want to insert the coordinates from google, you will need to set
# the first two coordinates for the upper left corner (-122.41, 39.31)
# and second two (-122.75, 39.55) will refer to lower right corner of the box
# Lastly: lat long from Google maps needs to be switched around (e.g. for lower corner 
# google maps will give you '39.55, -122.75'; you need to switch out around to read -122.75, 39.55)

betsiboka_coords_wgs84 = [37.26, -0.18, 37.30, -0.22]
betsiboka_bbox2 = BBox(bbox=betsiboka_coords_wgs84, crs=CRS.WGS84)


my_url = 'https://raw.githubusercontent.com/sentinel-hub/custom-scripts/master/sentinel-2/markuse_fire/script.js'
my_url_2 = 'https://raw.githubusercontent.com/sentinel-hub/custom-scripts/master/sentinel-2/nbr/script.js'

evalscripturl_wms_request = WmsRequest(layer='TRUE-COLOR-S2-L1C', # Layer parameter can be any existing layer
                                       bbox=betsiboka_bbox2,
                                       time='2019-02-28',
                                       width=512,
                                       config=config,
                                       custom_url_params={CustomUrlParam.EVALSCRIPTURL: my_url})

evalscripturl_wms_data = evalscripturl_wms_request.get_data()
plot_image(evalscripturl_wms_data[0])
# Out:
# C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\sentinelhub\data_collections.py:746: SHDeprecationWarning: In the future please specify data_collection parameter, for now taking DataCollection.SENTINEL2_L1C
#   warnings.warn('In the future please specify data_collection parameter, for now taking '

# %%
# Tip: if you want to insert the coordinates from google, you will need to set
# the first two coordinates for the upper left corner (-122.41, 39.31)
# and second two (-122.75, 39.55) will refer to lower right corner of the box
# Lastly: lat long from Google maps needs to be switched around (e.g. for lower corner 
# google maps will give you '39.55, -122.75'; you need to switch out around to read -122.75, 39.55)


betsiboka_coords_wgs84 = [37.41, 36.15, 37.45, 36.19]
betsiboka_bbox2 = BBox(bbox=betsiboka_coords_wgs84, crs=CRS.WGS84)


my_url = 'https://raw.githubusercontent.com/sentinel-hub/custom-scripts/master/sentinel-2/markuse_fire/script.js'
my_url_2 = 'https://raw.githubusercontent.com/sentinel-hub/custom-scripts/master/sentinel-2/nbr/script.js'

evalscripturl_wms_request = WmsRequest(layer='TRUE-COLOR-S2-L1C', # Layer parameter can be any existing layer
                                       bbox=betsiboka_bbox2,
                                       time='2016-02-16',
                                       width=512,
                                       config=config,
                                       custom_url_params={CustomUrlParam.EVALSCRIPTURL: my_url})

evalscripturl_wms_data = evalscripturl_wms_request.get_data()
plot_image(evalscripturl_wms_data[0])

# %%
# set the autoreload and the inline plotting for matplotlib
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# data manipulation
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# image manipulations
from skimage.filters import threshold_otsu, sobel
from skimage.morphology import erosion, dilation, opening, closing, white_tophat, disk

# GIS related
import geopandas as gpd
from shapely.wkt import loads
from shapely.geometry import shape, MultiPolygon, Polygon

# eo-learn related
from eolearn.core import EOTask, EOPatch, LinearWorkflow, Dependency, FeatureType, LoadFromDisk, SaveToDisk
from eolearn.io import S2L1CWCSInput 
from eolearn.mask import AddCloudMaskTask, AddValidDataMaskTask, get_s2_pixel_cloud_detector
from eolearn.features import SimpleFilterTask
from eolearn.geometry import VectorToRaster

# Sentinel Hub
from sentinelhub import BBox, CRS

# water observatory backend
import sys
sys.path.append('./water-observatory-backend/src')
#from visualisation import plot_water_body
from geom_utils import get_bbox
from s2_water_extraction import get_water_level_optical
from visualisation import draw_multi, draw_poly

# other
import urllib.request as request
import json
from datetime import datetime
from shapely.wkt import loads
# Out:
# [autoreload of numpy.core.multiarray failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\core\multiarray.py", line 16, in <module>
#     from ._multiarray_umath import (
# ImportError: cannot import name '_from_dlpack' from 'numpy.core._multiarray_umath' (C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\core\_multiarray_umath.cp38-win_amd64.pyd)
# ]
# [autoreload of numpy.core.numeric failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\core\numeric.py", line 10, in <module>
#     from .multiarray import (
# ImportError: cannot import name '_from_dlpack' from 'numpy.core.multiarray' (C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\core\multiarray.py)
# ]
# [autoreload of numpy.core._add_newdocs failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\core\_add_newdocs.py", line 1576, in <module>
#     add_newdoc('numpy.core.multiarray', '_from_dlpack',
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\core\function_base.py", line 521, in add_newdoc
#     new = getattr(__import__(place, globals(), {}, [obj]), obj)
# AttributeError: module 'numpy.core.multiarray' has no attribute '_from_dlpack'
# ]
# [autoreload of numpy.core._add_newdocs_scalars failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\core\_add_newdocs_scalars.py", line 243, in <module>
#     add_newdoc('numpy.core.numerictypes', "integer", ('is_integer',
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\core\function_base.py", line 526, in add_newdoc
#     _add_docstring(getattr(new, attr), docstring.strip(), warn_on_python)
# AttributeError: type object 'numpy.integer' has no attribute 'is_integer'
# ]
# [autoreload of numpy.lib.scimath failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: sqrt() requires a code object with 0 free vars, not 3
# ]
# [autoreload of numpy.lib.stride_tricks failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: sliding_window_view() requires a code object with 0 free vars, not 3
# ]
# [autoreload of numpy.linalg.linalg failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\linalg\linalg.py", line 84, in <module>
#     _linalg_error_extobj = _determine_error_states()
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\linalg\linalg.py", line 77, in _determine_error_states
#     with errstate(invalid='call', over='ignore',
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\core\_ufunc_config.py", line 432, in __enter__
#     self.oldcall = seterrcall(self.call)
# ValueError: Only callable can be used as callback
# ]
# [autoreload of numpy.matrixlib failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\matrixlib\__init__.py", line 6, in <module>
#     __all__ = defmatrix.__all__
# NameError: name 'defmatrix' is not defined
# ]
# [autoreload of numpy.lib failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\lib\__init__.py", line 44, in <module>
#     __all__ += type_check.__all__
# NameError: name 'type_check' is not defined
# ]
# [autoreload of numpy.fft failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: fft() requires a code object with 0 free vars, not 3
# ]
# [autoreload of numpy.ma.core failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\ma\core.py", line 8191, in <module>
#     frombuffer = _convert2ma(
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\ma\core.py", line 8103, in __init__
#     self.__doc__ = self.getdoc(np_ret, np_ma_ret)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\ma\core.py", line 8111, in getdoc
#     doc = self._replace_return_type(doc, np_ret, np_ma_ret)
# RuntimeError: Failed to replace `out : ndarray` with `out: MaskedArray`. The documentation string for return type, out : ndarray, is not found in the docstring for `np.frombuffer`. Fix the docstring for `np.frombuffer` or update the expected string for return type.
# ]
# [autoreload of numpy failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\__init__.py", line 195, in <module>
#     core.numerictypes.typeDict,
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\core\__init__.py", line 161, in __getattr__
#     raise AttributeError(f"Module {__name__!r} has no attribute {name!r}")
# AttributeError: Module 'numpy.core' has no attribute 'numerictypes'
# ]
# [autoreload of numpy.testing._private.utils failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\testing\_private\utils.py", line 53, in <module>
#     HAS_LAPACK64 = numpy.linalg.lapack_lite._ilp64
# AttributeError: module 'numpy.linalg' has no attribute 'lapack_lite'
# ]
# [autoreload of numpy.testing failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\numpy\testing\__init__.py", line 17, in <module>
#     __all__ = _private.utils.__all__ + ['TestCase', 'run_module_suite']
# NameError: name '_private' is not defined
# ]
# [autoreload of pandas._config.config failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 317, in update_class
#     update_instances(old, new)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 280, in update_instances
#     ref.__class__ = new
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\_config\config.py", line 221, in __setattr__
#     raise OptionError("You can only set the value of existing options")
# pandas._config.config.OptionError: 'You can only set the value of existing options'
# ]
# [autoreload of pandas.core.arrays.base failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\arrays\base.py", line 80, in <module>
#     from pandas.core.array_algos.quantile import quantile_with_mask
# ImportError: cannot import name 'quantile_with_mask' from 'pandas.core.array_algos.quantile' (C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\array_algos\quantile.py)
# ]
# [autoreload of pandas.core.arrays.masked failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\arrays\masked.py", line 72, in <module>
#     from pandas.core.array_algos.quantile import quantile_with_mask
# ImportError: cannot import name 'quantile_with_mask' from 'pandas.core.array_algos.quantile' (C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\array_algos\quantile.py)
# ]
# [autoreload of pandas.core.arrays.boolean failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\arrays\boolean.py", line 50, in <module>
#     class BooleanDtype(BaseMaskedDtype):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\dtypes\base.py", line 413, in register_extension_dtype
#     _registry.register(cls)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\dtypes\base.py", line 443, in register
#     raise ValueError("can only register pandas extension dtypes")
# ValueError: can only register pandas extension dtypes
# ]
# [autoreload of pandas.core.arrays._mixins failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\arrays\_mixins.py", line 56, in <module>
#     from pandas.core.array_algos.quantile import quantile_with_mask
# ImportError: cannot import name 'quantile_with_mask' from 'pandas.core.array_algos.quantile' (C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\array_algos\quantile.py)
# ]
# [autoreload of pandas.core.arrays.categorical failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: astype() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.core.arrays.datetimelike failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: astype() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.core.arrays.integer failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\arrays\integer.py", line 433, in <module>
#     class Int8Dtype(_IntegerDtype):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\dtypes\base.py", line 413, in register_extension_dtype
#     _registry.register(cls)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\dtypes\base.py", line 443, in register
#     raise ValueError("can only register pandas extension dtypes")
# ValueError: can only register pandas extension dtypes
# ]
# [autoreload of pandas.core.arrays.floating failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\arrays\floating.py", line 359, in <module>
#     class Float32Dtype(FloatingDtype):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\dtypes\base.py", line 413, in register_extension_dtype
#     _registry.register(cls)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\dtypes\base.py", line 443, in register
#     raise ValueError("can only register pandas extension dtypes")
# ValueError: can only register pandas extension dtypes
# ]
# [autoreload of pandas.core.arrays.sparse.array failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\arrays\sparse\array.py", line 87, in <module>
#     from pandas.core.indexers import (
# ImportError: cannot import name 'unpack_tuple_and_ellipses' from 'pandas.core.indexers' (C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\indexers.py)
# ]
# [autoreload of pandas.core.indexes.base failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\indexes\base.py", line 36, in <module>
#     from pandas._libs.missing import is_float_nan
# ImportError: cannot import name 'is_float_nan' from 'pandas._libs.missing' (C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\_libs\missing.cp38-win_amd64.pyd)
# ]
# [autoreload of pandas.core.arrays.interval failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: astype() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.core.arrays.string_arrow failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\arrays\string_arrow.py", line 59, in <module>
#     from pandas.core.indexers import (
# ImportError: cannot import name 'unpack_tuple_and_ellipses' from 'pandas.core.indexers' (C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\indexers.py)
# ]
# [autoreload of pandas.core.indexes.extension failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __eq__() requires a code object with 1 free vars, not 2
# ]
# [autoreload of pandas.core.indexes.category failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\indexes\category.py", line 86, in <module>
#     class CategoricalIndex(NDArrayBackedExtensionIndex):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\indexes\extension.py", line 127, in wrapper
#     meth = _inherit_from_data(name, delegate, cache=cache, wrap=wrap)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\indexes\extension.py", line 52, in _inherit_from_data
#     attr = getattr(delegate, name)
# AttributeError: type object 'Categorical' has no attribute 'tolist'
# ]
# [autoreload of pandas.core.indexes.datetimelike failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __array_wrap__() requires a code object with 1 free vars, not 0
# ]
# [autoreload of pandas.core.indexes.datetimes failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: _maybe_cast_slice_bound() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.core.indexes.multi failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: _difference() requires a code object with 1 free vars, not 0
# ]
# [autoreload of pandas.core.indexes.interval failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: astype() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.core.indexes.period failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: _maybe_cast_slice_bound() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.core.indexes.range failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: delete() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.io.common failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\io\common.py", line 254, in <module>
#     @doc(compression_options=_shared_docs["compression_options"] % "filepath_or_buffer")
# KeyError: 'compression_options'
# ]
# [autoreload of pandas.io.formats.format failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\io\formats\format.py", line 99, in <module>
#     from pandas.io.common import (
# ImportError: cannot import name 'check_parent_directory' from 'pandas.io.common' (C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\io\common.py)
# ]
# [autoreload of pandas.core.window.rolling failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\window\rolling.py", line 61, in <module>
#     from pandas.core.indexers.objects import (
# ModuleNotFoundError: No module named 'pandas.core.indexers.objects'; 'pandas.core.indexers' is not a package
# ]
# [autoreload of pandas.core.window.ewm failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\window\ewm.py", line 30, in <module>
#     from pandas.core.indexers.objects import (
# ModuleNotFoundError: No module named 'pandas.core.indexers.objects'; 'pandas.core.indexers' is not a package
# ]
# [autoreload of pandas.core.window.expanding failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\window\expanding.py", line 22, in <module>
#     from pandas.core.indexers.objects import (
# ModuleNotFoundError: No module named 'pandas.core.indexers.objects'; 'pandas.core.indexers' is not a package
# ]
# [autoreload of pandas.core.series failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
# ...
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\arrays\sparse\array.py", line 87, in <module>
#     from pandas.core.indexers import (
# ImportError: cannot import name 'unpack_tuple_and_ellipses' from 'pandas.core.indexers' (C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\indexers.py)
# ]
# [autoreload of pandas.core.indexes.base failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\indexes\base.py", line 36, in <module>
#     from pandas._libs.missing import is_float_nan
# ImportError: cannot import name 'is_float_nan' from 'pandas._libs.missing' (C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\_libs\missing.cp38-win_amd64.pyd)
# ]
# [autoreload of pandas.core.arrays.string_arrow failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\arrays\string_arrow.py", line 59, in <module>
#     from pandas.core.indexers import (
# ImportError: cannot import name 'unpack_tuple_and_ellipses' from 'pandas.core.indexers' (C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\indexers.py)
# ]
# [autoreload of pandas.core.window.rolling failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\window\rolling.py", line 61, in <module>
#     from pandas.core.indexers.objects import (
# ModuleNotFoundError: No module named 'pandas.core.indexers.objects'; 'pandas.core.indexers' is not a package
# ]
# [autoreload of pandas.core.window.ewm failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\window\ewm.py", line 30, in <module>
#     from pandas.core.indexers.objects import (
# ModuleNotFoundError: No module named 'pandas.core.indexers.objects'; 'pandas.core.indexers' is not a package
# ]
# [autoreload of pandas.core.window.expanding failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\window\expanding.py", line 22, in <module>
#     from pandas.core.indexers.objects import (
# ModuleNotFoundError: No module named 'pandas.core.indexers.objects'; 'pandas.core.indexers' is not a package
# ]
# [autoreload of pandas.core.series failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\series.py", line 202, in <module>
#     class Series(base.IndexOpsMixin, NDFrame):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\core\series.py", line 314, in Series
#     base.IndexOpsMixin.hasnans.fget,  # type: ignore[attr-defined]
# AttributeError: 'pandas._libs.properties.CachedProperty' object has no attribute 'fget'
# ]
# [autoreload of pandas.api.indexers failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\api\indexers\__init__.py", line 6, in <module>
#     from pandas.core.indexers.objects import (
# ModuleNotFoundError: No module named 'pandas.core.indexers.objects'; 'pandas.core.indexers' is not a package
# ]
# [autoreload of pandas._testing failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\_testing\__init__.py", line 974, in <module>
#     cython_table = pd.core.common._cython_table.items()
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\pandas\__init__.py", line 261, in __getattr__
#     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
# AttributeError: module 'pandas' has no attribute 'core'
# ]
# [autoreload of geopandas._config failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 317, in update_class
#     update_instances(old, new)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 280, in update_instances
#     ref.__class__ = new
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\geopandas\_config.py", line 36, in __setattr__
#     raise AttributeError(msg)
# AttributeError: You can only set the value of existing options
# ]
# [autoreload of geopandas.io.file failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\geopandas\io\file.py", line 6, in <module>
#     import fiona
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\fiona\__init__.py", line 88, in <module>
#     with fiona._loading.add_gdal_dll_directories():
# AttributeError: partially initialized module 'fiona' has no attribute '_loading' (most likely due to a circular import)
# ]
# [autoreload of geopandas.tools.crs failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\geopandas\tools\crs.py", line 4, in <module>
#     import fiona.crs
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\fiona\__init__.py", line 88, in <module>
#     with fiona._loading.add_gdal_dll_directories():
# AttributeError: partially initialized module 'fiona' has no attribute '_loading' (most likely due to a circular import)
# ]
# [autoreload of geopandas.tools.geocoding failed: Traceback (most recent call last):
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\geopandas\tools\geocoding.py", line 8, in <module>
#     from fiona.crs import from_epsg
#   File "C:\Users\amelt\anaconda3\envs\tutorial\lib\site-packages\fiona\__init__.py", line 88, in <module>
#     with fiona._loading.add_gdal_dll_directories():
# AttributeError: partially initialized module 'fiona' has no attribute '_loading' (most likely due to a circular import)
# ]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_53716/2421454958.py in <module>
#      20
#      21 # eo-learn related
# ---> 22 from eolearn.core import EOTask, EOPatch, LinearWorkflow, Dependency, FeatureType, LoadFromDisk, SaveToDisk
#      23 from eolearn.io import S2L1CWCSInput
#      24 from eolearn.mask import AddCloudMaskTask, AddValidDataMaskTask, get_s2_pixel_cloud_detector
#
# ModuleNotFoundError: No module named 'eolearn'
